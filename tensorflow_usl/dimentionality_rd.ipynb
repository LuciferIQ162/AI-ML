# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist, fashion_mnist
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# Out:
# 2025-10-05 10:12:25.098156: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#define the autoencoder model
input_layer = Input(shape=(784,))
encoded = Dense(64, activation='relu')(input_layer)
bottleneck = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(bottleneck)
output_layer = Dense(784, activation = 'sigmoid')(decoded)
autoencoder = Model(input_layer, output_layer)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759639372.519261   89820 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2307 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
#load and preprocess the data mnist
(x_train, _), (_, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_train = x_train.reshape(-1, 28 * 28)

# %%
#compile the dr model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

#train the autoencoder
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True,
                validation_split=0.2)
# Out:
# Epoch 1/50
# 2025-10-05 10:13:00.502885: I external/local_xla/xla/service/service.cc:163] XLA service 0x7feabc003ac0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-05 10:13:00.502904: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2025-10-05 10:13:00.520356: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-05 10:13:00.668435: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 100/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4638
# I0000 00:00:1759639381.662173   90369 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.3870 - val_loss: 0.1849
# Epoch 2/50
# ...

# %%
#evaluating the dimentionality reduction model
encoder = Model(input_layer, bottleneck)
compressed_data = encoder.predict(x_train)

#Use the t-SNE model for 2D visualization
tsne = TSNE(n_components=2)
compressed_2d = tsne.fit_transform(compressed_data)

#plot the compressed data
plt.scatter(compressed_2d[:, 0], compressed_2d[:, 1], c=labels, cmap='virdis')
plt.colorbar()
plt.show()
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step
